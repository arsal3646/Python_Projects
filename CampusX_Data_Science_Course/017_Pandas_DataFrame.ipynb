# %% [markdown]
# # Pandas - DataFrame

# %%
# Series is one-dimensional while DataFrame is two-dimensional. 
# A Series can be thought of as a single column of data, while a DataFrame is a collection of Series that share the same index.

# DataFrame is just tabular data structure with labeled axes (rows and columns). 
# It can be thought of as a dictionary of Series objects, where each Series represents a column in the DataFrame.

# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from pathlib import Path

file_name = "batsman_runs_ipl.csv"

for folder in [Path.cwd(), *Path.cwd().parents]:
    matches = list(folder.rglob(file_name))
    if matches:
        print("Found file here:")
        print(matches[0])
        break
else:
    print("File not found on this computer")
# Out:
# Found file here:
# /Users/arsalanafridi/Documents/GitHub/Python_Projects/Python_Projects/CampusX_Data_Science_Course/018_DataSets_DataFrames/batsman_runs_ipl.csv

# %%
import pandas as pd

batsman = pd.read_csv("017_DataSets_Pandas_DataFrames/batsman_runs_ipl.csv")
batsman.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
import pandas as pd

data_folder = "017_DataSets_Pandas_DataFrames"

diabetes = pd.read_csv(f"{data_folder}/diabetes.csv")
ipl_matches = pd.read_csv(f"{data_folder}/ipl-matches.csv")
movies = pd.read_csv(f"{data_folder}/movies.csv")

diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
ipl_matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# creating a DataFrame using List of Lists

import pandas as pd

student_data = [
    [100, 80, 10],
    [90, 70, 7],
    [120, 100, 14],
    [80, 50, 2]
]

students_df = pd.DataFrame(student_data, columns=["IQ", "Marks", "Salary_per_year"])

students_df.head()

print(students_df.head())
# Out:
#     IQ  Marks  Salary_per_year
# 0  100     80               10
# 1   90     70                7
# 2  120    100               14
# 3   80     50                2

# %%
# creating a DataFrame using Dictionaries

students_dict = {
    'iq':[100,90,120,80],
    "marks" : [80,70,100,50],
    "salary_per_year" : [10,7,14,2]
}

students_df_dict = pd.DataFrame(students_dict)
students_df_dict.head()
# Out:
#     iq  marks  salary_per_year
# 0  100     80               10
# 1   90     70                7
# 2  120    100               14
# 3   80     50                2

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
ipl_matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl_matches.sample(10)
# Out:
#           ID       City        Date   Season MatchNumber  \
# 640   548369      Delhi  2012-05-15     2012          64
# 165  1216528        NaN  2020-10-13  2020/21          29
# 282  1136592      Delhi  2018-05-02     2018          32
# 403   980959  Bangalore  2016-05-02     2016          30
# 483   829721  Ahmedabad  2015-04-14     2015           9
# 391   980983  Hyderabad  2016-05-12     2016          42
# 206  1178423  Hyderabad  2019-04-29     2019          48
# 131  1254060    Chennai  2021-04-11     2021           3
# 730   501243  Hyderabad  2011-05-05     2011          46
# 782   419158    Kolkata  2010-04-17  2009/10          53
#
#                            Team1                  Team2  \
# 640             Delhi Daredevils        Kings XI Punjab
# 165          Chennai Super Kings    Sunrisers Hyderabad
# 282             Delhi Daredevils       Rajasthan Royals
# 403  Royal Challengers Bangalore  Kolkata Knight Riders
# ...

# %%
ipl_matches.tail(10)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 940  335991  Chandigarh  2008-04-25  2007/08          10
# 941  335990   Hyderabad  2008-04-24  2007/08           9
# 942  335989     Chennai  2008-04-23  2007/08           8
# 943  335988   Hyderabad  2008-04-22  2007/08           7
# 944  335987      Jaipur  2008-04-21  2007/08           6
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 940              Kings XI Punjab               Mumbai Indians
# 941              Deccan Chargers             Rajasthan Royals
# 942          Chennai Super Kings               Mumbai Indians
# 943              Deccan Chargers             Delhi Daredevils
# ...

# %% [markdown]
# # Attributes of DataFrame

# %%
# shape of a DataFrame

movies.shape
# Out:
# (1629, 18)

# %%
ipl_matches.shape
# Out:
# (950, 20)

# %%
diabetes.shape
# Out:
# (768, 9)

# %%
# dtypes of a DataFrame

diabetes.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
movies.dtypes
# Out:
# title_x                 str
# imdb_id                 str
# poster_path             str
# wiki_link               str
# title_y                 str
# original_title          str
# is_adult              int64
# year_of_release       int64
# runtime                 str
# genres                  str
# imdb_rating         float64
# imdb_votes            int64
# story                   str
# summary                 str
# tagline                 str
# actors                  str
# wins_nominations        str
# release_date            str
# dtype: object

# %%
ipl_matches.dtypes
# Out:
# ID                   int64
# City                   str
# Date                   str
# Season                 str
# MatchNumber            str
# Team1                  str
# Team2                  str
# Venue                  str
# TossWinner             str
# TossDecision           str
# SuperOver              str
# WinningTeam            str
# WonBy                  str
# Margin             float64
# method                 str
# Player_of_Match        str
# Team1Players           str
# Team2Players           str
# Umpire1                str
# Umpire2                str
# dtype: object

# %%
ipl_matches.dtypes
# Out:
# ID                   int64
# City                   str
# Date                   str
# Season                 str
# MatchNumber            str
# Team1                  str
# Team2                  str
# Venue                  str
# TossWinner             str
# TossDecision           str
# SuperOver              str
# WinningTeam            str
# WonBy                  str
# Margin             float64
# method                 str
# Player_of_Match        str
# Team1Players           str
# Team2Players           str
# Umpire1                str
# Umpire2                str
# dtype: object

# %%
# index of a DataFrame

ipl_matches.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
diabetes.index
# Out:
# RangeIndex(start=0, stop=768, step=1)

# %%
# columns 

ipl_matches.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='str')

# %%
# values of a DataFrame

students_df_dict.values
# Out:
# array([[100,  80,  10],
#        [ 90,  70,   7],
#        [120, 100,  14],
#        [ 80,  50,   2]])

# %%
ipl_matches.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
# head and tail of a DataFrame

diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# info of a DataFrame
diabetes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# in the above data we note important information about the data like 
# 1. number of rows
# 2. number of columns
# 3. column names
# 4. data types
# 5. memory usage
# This information is useful for understanding the structure of the DataFrame and for identifying any potential issues with the data.

# 768 means there are 768 rows in the DataFrame, and 9 means there are 9 columns in the DataFrame. 
# The column names are listed along with their data types.
# This can be useful for understanding the type of data contained in each column. 
# The memory usage indicates how much memory is being used to store the DataFrame in memory.

# Missing values in a DataFrame
# The above output shows that there are no missing values in the DataFrame, as all columns have 768 non-null entries.

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   str
#  1   imdb_id           1629 non-null   str
#  2   poster_path       1526 non-null   str
#  3   wiki_link         1629 non-null   str
#  4   title_y           1629 non-null   str
#  5   original_title    1629 non-null   str
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   str
#  9   genres            1629 non-null   str
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   str
#  13  summary           1629 non-null   str
#  14  tagline           557 non-null    str
#  15  actors            1624 non-null   str
#  16  wins_nominations  707 non-null    str
# ...

# %%
# There are many missing values in the DataFrame, as indicated by the number of non-null entries for each column.
# The total rows are 1629 in movies.info() while tagline has 557 non-null entries, 
# which means that there are 1629 - 557 = 1072 missing values in the tagline column.

# %%
ipl_matches.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    str
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    str
#  6   Team2            950 non-null    str
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
#  17  Team2Players     950 non-null    str
# ...

# %%
# describe() method in a DataFrame

ipl_matches.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
movies.describe()

# The describe() method provides a summary of the statistics for each column in the DataFrame, including 
# 1. count
# 2. mean
# 3. standard deviation
# 4. minimum
# 5. maximum
# 6. 25th percentile
# 7. 50th percentile (median)
# 8. 75th percentile

# Note: describe() method only works for numerical columns
 
# so if the DataFrame contains non-numerical columns, they will be excluded from the summary statistics.
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
# isnull() method in a DataFrame

# The isnull() method is used to detect missing values in a DataFrame.

movies.isnull()
# Out:
#       title_x  imdb_id  poster_path  wiki_link  title_y  original_title  \
# 0       False    False        False      False    False           False
# 1       False    False         True      False    False           False
# 2       False    False        False      False    False           False
# 3       False    False        False      False    False           False
# 4       False    False         True      False    False           False
# ...       ...      ...          ...        ...      ...             ...
# 1624    False    False        False      False    False           False
# 1625    False    False        False      False    False           False
# 1626    False    False         True      False    False           False
# 1627    False    False        False      False    False           False
# 1628    False    False        False      False    False           False
#
#       is_adult  year_of_release  runtime  genres  imdb_rating  imdb_votes  \
# ...

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# duplicated() method in a DataFrame

movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
ipl_matches.duplicated().sum()
# Out:
# np.int64(0)

# %%
# rename() function in a DataFrame

students_df.rename(columns = {
    'IQ': 'Intelligence Quotient',
    'Marks': 'Marks Obtained',
    'Salary_per_year': 'Annual Salary'
})

# Note: These are not permanent changes to the DataFrame. 
# If you want to make the changes permanent, you can use the inplace parameter and set it to True.
# Out:
#    Intelligence Quotient  Marks Obtained  Annual Salary
# 0                    100              80             10
# 1                     90              70              7
# 2                    120             100             14
# 3                     80              50              2

# %%
students_df
# Out:
#     IQ  Marks  Salary_per_year
# 0  100     80               10
# 1   90     70                7
# 2  120    100               14
# 3   80     50                2

# %%
# rename() function in a DataFrame with inplace parameter

# rename() function in a DataFrame

students_df.rename(columns = {
    'IQ': 'Intelligence Quotient',
    'Marks': 'Marks Obtained',
    'Salary_per_year': 'Annual Salary'
}, inplace=True)

# %%
students_df

# now we can see that the column names have been changed permanently in the DataFrame.
# Out:
#    Intelligence Quotient  Marks Obtained  Annual Salary
# 0                    100              80             10
# 1                     90              70              7
# 2                    120             100             14
# 3                     80              50              2

# %%
# how to fetch a column from a DataFrame

students_df['Intelligence Quotient']
# Out:
# 0    100
# 1     90
# 2    120
# 3     80
# Name: Intelligence Quotient, dtype: int64

# %%
# how to fetch multiple columns from a DataFrame

students_df[['Intelligence Quotient', 'Marks Obtained']]
# Out:
#    Intelligence Quotient  Marks Obtained
# 0                    100              80
# 1                     90              70
# 2                    120             100
# 3                     80              50

# %%
# how to fetch rows from a DataFrame

# there are two method for selecting rows from a DataFrame:
# 1. loc[] method - label-based indexing

# 2. iloc[] method - integer-based indexing

# %%
# first let us iloc

# # single row

movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
movies.iloc[5:]
# Out:
#                                title_x     imdb_id  \
# 5                          Soni (film)   tt6078866
# 6                        Fraud Saiyaan   tt5013008
# 7                           Bombairiya   tt4971258
# 8     Manikarnika: The Queen of Jhansi   tt6903440
# 9                     Thackeray (film)   tt7777196
# ...                                ...         ...
# 1624             Tera Mera Saath Rahen   tt0301250
# 1625              Yeh Zindagi Ka Safar   tt0298607
# 1626                   Sabse Bada Sukh   tt0069204
# 1627                             Daaka  tt10833860
# 1628                          Humsafar   tt2403201
#
#                                             poster_path  \
# 5     https://upload.wikimedia.org/wikipedia/en/thum...
# 6     https://upload.wikimedia.org/wikipedia/en/thum...
# 7     https://upload.wikimedia.org/wikipedia/en/thum...
# 8     https://upload.wikimedia.org/wikipedia/en/thum...
# 9     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# multiple rows

# %%
# fancy indexing

movies.iloc[[0,4,5]]  # This will return the rows at index 0, 4, and 5 from the movies DataFrame.
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
# loc[] searches on basis of labels

students_df_dict
# Out:
#     iq  marks  salary_per_year
# 0  100     80               10
# 1   90     70                7
# 2  120    100               14
# 3   80     50                2

# %%
students_df_dict.loc[2]  # This will return the row with label 2 from the students_df_dict DataFrame.
# Out:
# iq                 120
# marks              100
# salary_per_year     14
# Name: 2, dtype: int64

# %%
students_df_dict.loc[2:]  

# This will return all rows starting from the row with label 2 from the students_df_dict DataFrame.
# Out:
#     iq  marks  salary_per_year
# 2  120    100               14
# 3   80     50                2

# %%
movies.iloc[0:3,0:3] 

# this will fetch first three movies (rows) and first three columns (title, genre, and director) from the movies DataFrame.
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
# Filtering a DataFrame 

ipl_matches.head(10)
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %%
# Find Winner of the tournament

# for this we need to fetch FINAL match and then winner of that match.

mask = ipl_matches['MatchNumber'] == 'Final'

# now just bring Season (i.e. IPL year) and its Winning Team
new_df = ipl_matches[mask]
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# Another way is as below (using fancy indexing):

ipl_matches[ipl_matches['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super over finishes have occurred?

# Note: this happens when score of the two teams is same and then they go for super over.

ipl_matches[ipl_matches['SuperOver'] == 'Y']
# Out:
#           ID       City        Date   Season MatchNumber  \
# 114  1254077    Chennai  2021-04-25     2021          20
# 158  1216512  Abu Dhabi  2020-10-18  2020/21          35
# 159  1216517        NaN  2020-10-18  2020/21          36
# 184  1216547        NaN  2020-09-28  2020/21          10
# 192  1216493        NaN  2020-09-20  2020/21           2
# 203  1178426     Mumbai  2019-05-02     2019          51
# 244  1175365      Delhi  2019-03-30     2019          10
# 339  1082625     Rajkot  2017-04-29     2017          35
# 474   829741  Ahmedabad  2015-04-21     2015          18
# 533   729315  Abu Dhabi  2014-04-29     2014          19
# 608   598017  Bangalore  2013-04-16     2013          21
# 621   598004  Hyderabad  2013-04-07     2013           7
# 819   419121    Chennai  2010-03-21  2009/10          16
# 883   392190  Cape Town  2009-04-23     2009          10
#
#                            Team1                        Team2  \
# ...

# %%
ipl_matches[ipl_matches['SuperOver'] == 'Y'].shape

# this will tell us how many matches have Super Over. We can see that there were 14 such matches as there are 14 matches
# Out:
# (14, 20)

# %%
# just to filter out rows, just add [0] to the shape

ipl_matches[ipl_matches['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
ipl_matches.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='str')

# %%
# how many matches did CSK team win in Kolkata

ipl_matches[(ipl_matches['City'] == 'Kolkata') & (ipl_matches['WinningTeam'] == 'Chennai Super Kings')]

# Note: this is not logical AND 'and' but we used & which is a bit-wise operator. 
# This is because we are working with Series objects and not single boolean values.
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
ipl_matches[(ipl_matches['City'] == 'Kolkata') & (ipl_matches['WinningTeam'] == 'Chennai Super Kings')].shape[0]

# So there are 5 such matches where CSK won in Kolkata.
# Out:
# 5

# %%
# toss winner benefits the team or not? 
# we can check this by checking how many matches were won by the team that won the toss.

ipl_matches[ipl_matches['TossWinner'] == ipl_matches['WinningTeam']]
# Out:
#           ID         City        Date   Season  MatchNumber  \
# 1    1312199    Ahmedabad  2022-05-27     2022  Qualifier 2
# 3    1312197      Kolkata  2022-05-24     2022  Qualifier 1
# 5    1304115       Mumbai  2022-05-21     2022           69
# 8    1304112  Navi Mumbai  2022-05-18     2022           66
# 11   1304109       Mumbai  2022-05-15     2022           63
# ..       ...          ...         ...      ...          ...
# 935   335996    Bangalore  2008-04-28  2007/08           15
# 937   335994       Mumbai  2008-04-27  2007/08           14
# 939   335992    Bangalore  2008-04-26  2007/08           12
# 941   335990    Hyderabad  2008-04-24  2007/08            9
# 948   335983   Chandigarh  2008-04-19  2007/08            2
#
#                            Team1                  Team2  \
# 1    Royal Challengers Bangalore       Rajasthan Royals
# 3               Rajasthan Royals         Gujarat Titans
# 5                 Delhi Capitals         Mumbai Indians
# ...

# %%
ipl_matches.shape[0]

# Total number of matches played in IPL is 950. Out of these, 489 matches were won by the team that won the toss.
# Out:
# 950

# %%
ipl_matches[ipl_matches['TossWinner'] == ipl_matches['WinningTeam']].shape[0]

# In 489 matches out of 950 matches, the team that won the toss also won the match. This suggests that winning the toss may provide a significant advantage in IPL matches.
# Out:
# 489

# %%
ipl_matches[ipl_matches['TossWinner'] == ipl_matches['WinningTeam']].shape[0] / ipl_matches.shape[0]

# there is a very slight advantage of winning the toss in IPL matches 
# as the team that won the toss won the match in 51.47% of the cases. 
# However, this advantage is not very significant and may not be a decisive factor in determining the outcome of a match.
# Out:
# 0.5147368421052632

# %%
# find movies with rating great than 8 and votes greater than 10000

movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]

# We get 43 such movies that have rating greater than 8 and votes greater than 10000.
# Out:
# 43

# %%
# find movies with rating great than 8.5 and votes greater than 10000

movies[(movies['imdb_rating'] > 8.5) & (movies['imdb_votes'] > 10000)].shape[0]

# We get ZERO such movies that have rating greater than 8.5 and votes greater than 10000.
# Out:
# 0

# %%
# action movies with rating higher than 7.5
# we want to apply split

movies['genres']
# Out:
# 0       Action|Drama|War
# 1                    War
# 2        Biography|Drama
# 3            Crime|Drama
# 4                  Drama
#               ...
# 1624               Drama
# 1625               Drama
# 1626        Comedy|Drama
# 1627              Action
# 1628       Drama|Romance
# Name: genres, Length: 1629, dtype: str

# %%
# first convert it to string. 





movies['genres'].str

# %%
# then, split it using "|" 
 
movies['genres'].str.split("|")

# this will create a list such that
# Out:
# 0       [Action, Drama, War]
# 1                      [War]
# 2         [Biography, Drama]
# 3             [Crime, Drama]
# 4                    [Drama]
#                 ...
# 1624                 [Drama]
# 1625                 [Drama]
# 1626         [Comedy, Drama]
# 1627                [Action]
# 1628        [Drama, Romance]
# Name: genres, Length: 1629, dtype: object

# %%
# then we can use apply() method to apply a function to each element of the Series.

mask1 = movies['genres'].str.split("|").apply(lambda x: 'Action' in x)
mask1

# what this does is that it will return a boolean Series where, 
# each element is True if the corresponding movie has 'Action' in its genres, and False otherwise.

# this is a very useful technique for filtering a DataFrame based on the values in a column that contains lists or strings.
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627     True
# 1628    False
# Name: genres, Length: 1629, dtype: bool

# %%
mask2 = movies['imdb_rating'] > 7.5
mask2
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628     True
# Name: imdb_rating, Length: 1629, dtype: bool

# %%
movies[mask1 & mask2]

# why is the teacher using "mask" names? 
# it is a common convention to use the term "mask" when referring to a boolean Series that is used to filter a DataFrame.
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
movies[mask1 & mask2].shape[0]
# Out:
# 33

# %%
# another way is to use the str.contains() method to check if the 'genres' column contains the string 'Action'.
# the code will be as below: 

movies[movies['genres'].str.contains('Action') & (movies['imdb_rating'] > 7.5)]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %% [markdown]
# # Studied until 1 hour 42 min
