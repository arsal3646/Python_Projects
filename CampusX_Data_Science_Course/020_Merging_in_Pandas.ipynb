# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

courses = pd.read_csv('/Users/arsalanafridi/Documents/GitHub/Python_Projects/Python_Projects/CampusX_Data_Science_Course/020_DataSets_Merging/courses.csv')
students = pd.read_csv('/Users/arsalanafridi/Documents/GitHub/Python_Projects/Python_Projects/CampusX_Data_Science_Course/020_DataSets_Merging/students.csv')
nov = pd.read_csv('/Users/arsalanafridi/Documents/GitHub/Python_Projects/Python_Projects/CampusX_Data_Science_Course/020_DataSets_Merging/reg-month1.csv')
dec = pd.read_csv('/Users/arsalanafridi/Documents/GitHub/Python_Projects/Python_Projects/CampusX_Data_Science_Course/020_DataSets_Merging/reg-month2.csv')
matches = pd.read_csv('/Users/arsalanafridi/Documents/GitHub/Python_Projects/Python_Projects/CampusX_Data_Science_Course/020_DataSets_Merging/matches.csv')
delivery = pd.read_csv('/Users/arsalanafridi/Documents/GitHub/Python_Projects/Python_Projects/CampusX_Data_Science_Course/020_DataSets_Merging/deliveries.csv')

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
matches
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
nov
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
nov.shape

# this means 25 students registered in November and 28 students registered in December.
# Out:
# (25, 2)

# %%
dec.shape
# Out:
# (28, 2)

# %%
delivery
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
# pd.concat

# this is used to combine two dataframes. It can be used to combine dataframes vertically or horizontally.

# for example we can concatenate the two dataframes nov and dec vertically to get a single dataframe with all the students 
# who registered in November and December.

all_students = pd.concat([nov, dec])

all_students.shape

# this will 25 +28 = 53 students in total.
# Out:
# (53, 2)

# %%
all_students.head(30)

# You will notice here that after row 23 (end of nov dataframe), the index starts from 0 again. 
# This is because the index is not reset after concatenation. 
# We can reset the index using the reset_index() method.
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9

# %%
# we can reset the index of the all_students dataframe using the reset_index() method. 
# We can also drop the old index using the drop=True parameter.
all_students = all_students.reset_index(drop=True)
all_students
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
# also we can use ignore_index=True parameter in the concat() method to reset the index after concatenation.
all_students = pd.concat([nov, dec], ignore_index=True)
all_students
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
# another way is to use the append() method. 
# This method is used to append rows of one dataframe to another dataframe.

# but this method is deprecated and will be removed in a future version.

# %%
multi = pd.concat([nov, dec], keys=['nov', 'dec'])

# This will create a multi-index dataframe with the keys 'nov' and 'dec' as the first level of the index.

# %%
# loc is for index based selection and iloc is for position based selection.

multi.loc['dec']
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
# what if we want to select the first 5 rows of the dec dataframe from the multi-index dataframe?

multi.loc['dec'].iloc[:5]
# Out:
#    student_id  course_id
# 0           3          5
# 1          16          7
# 2          12         10
# 3          12          1
# 4          14          9

# %%
multi.loc['nov'].iloc[0]    # this will give the first row of the nov dataframe from the multi-index dataframe.

# %%
# we can stack horizontally as well. 
# For example, we can concatenate the two dataframes nov and dec horizontally to get a single dataframe with all the students 
# who registered in November and December.

pd.concat([nov, dec], axis=1)
# Out:
#     student_id  course_id  student_id  course_id
# 0         23.0        1.0           3          5
# 1         15.0        5.0          16          7
# 2         18.0        6.0          12         10
# 3         23.0        4.0          12          1
# 4         16.0        9.0          14          9
# 5         18.0        1.0           7          7
# 6          1.0        1.0           7          2
# 7          7.0        8.0          16          3
# 8         22.0        3.0          17         10
# 9         15.0        1.0          11          8
# 10        19.0        4.0          14          6
# 11         1.0        6.0          12          5
# 12         7.0       10.0          12          7
# 13        11.0        7.0          18          8
# 14        13.0        3.0           1         10
# 15        24.0        4.0           1          9
# 16        21.0        1.0           2          5
# 17        16.0        5.0           7          6
# ...

# %%
pd.concat([nov, dec], axis=1).shape

# note the NaN values in the last 3 rows of the nov dataframe. 
# This is because the nov dataframe has 25 rows and the dec dataframe has 28 rows.
# It was automatically filled with NaN values to match the number of rows in the dec dataframe. 
# Who did this automatically? Pandas did this automatically.
# Out:
# (28, 4)

# %% [markdown]
# # watched the video until min 29
