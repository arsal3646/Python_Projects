# %% [markdown]
# # Pandas (Series)

# %%
# Why Pandas? 

# Pandas is a powerful and flexible open-source data analysis and manipulation library for Python. 

# It provides data structures like DataFrames and Series that make it easy to work with structured data. 

# Here are some reasons why Pandas is widely used:  
# 01. Easy to use.
# 02. Efficient: Pandas is built on top of NumPy - fast and efficient data processing, even with large datasets.
# 03. Versatile: Pandas can handle a wide variety of data formats, including CSV, Excel, SQL databases, etc.
# 04. Integration: Pandas integrates well with other Python libraries, such as Matplotlib, Scikit-learn.
# 05. Community support
# 06. Data Cleaning: 
#      - Pandas provides robust tools for cleaning and preparing data, including:
#           1. handling missing values
#           2. handling duplicates
#           3. handling inconsistent data types

# 07. Data Transformation: Pandas allows for easy reshaping and pivoting of data
# 08. Performance: Pandas is optimized for performance, allowing for efficient data manipulation and analysis
# 09. Visualization: Pandas has built-in support for basic data visualization
# 10. Documentation: Pandas has comprehensive documentation and tutorials
# 11. Pandas is open-source software
# 12. Data Alignment: Pandas automatically aligns data for you when performing operations on different datasets
# 13. Time Series Analysis: Pandas provides specialized functionality for working with time series data
# 14. Grouping and Aggregation: Pandas makes it easy to group data by one or more keys and perform aggregate functions
# 15. Extensibility: Pandas can be extended with custom functions and methods

# %%
# always import pandas and numpy at the beginning of your script

import numpy as np
import pandas as pd

# %%
# What is Series? 

# A Series is a 1D labeled array capable of holding any data type (integers, strings, float, Python objects, etc.).
# The labels, also known as the index, allow for easy access and manipulation of data.  

# We can create a Series from a list, NumPy array, or dictionary.

# %%
# Series of strings

countries = ['Pakistan', 'India', 'Bangladesh','Afghanistan', 'Nepal', 'Sri Lanka', 'Bhutan', 'Maldives']   

pd.Series(countries)

# Series is a class inside Pandas library. 
# We can create a Series object by calling the Series class and passing in the data we want to store in the Series.
# Out:
# 0       Pakistan
# 1          India
# 2     Bangladesh
# 3    Afghanistan
# 4          Nepal
# 5      Sri Lanka
# 6         Bhutan
# 7       Maldives
# dtype: str

# %%
# Series of integers

runs_Kohli = [183, 160, 122, 97, 82, 70, 65, 55]

pd.Series(runs_Kohli)
# Out:
# 0    183
# 1    160
# 2    122
# 3     97
# 4     82
# 5     70
# 6     65
# 7     55
# dtype: int64

# %%
# Custom index instead of 0,1,2,3,4,5,6,7

marks_Arsalan = [85, 90, 78, 92, 88]
subjects = ['Math', 'Science', 'English', 'History', 'Geography']

pd.Series(marks_Arsalan, index=subjects)
# Out:
# Math         85
# Science      90
# English      78
# History      92
# Geography    88
# dtype: int64

# %%
marks_series = pd.Series(marks_Arsalan, index=subjects, name='Arsalan ke Marks')

marks_series
# the name is like a title or ID for the Series. 
# It can be useful when working with multiple Series or when displaying the data in a DataFrame.
# Out:
# Math         85
# Science      90
# English      78
# History      92
# Geography    88
# Name: Arsalan ke Marks, dtype: int64

# %%
# Series from dictionary

marks_dict = {
    'Math': 85,
    'Science' : 90,
    'English' : 78,
    'History' : 92,
    'Geography' : 88
}

marks_dict
# Out:
# {'Math': 85, 'Science': 90, 'English': 78, 'History': 92, 'Geography': 88}

# %% [markdown]
# # Series Attributes

# %%
# size of a series

marks_series.size
# Out:
# 5

# %%
# data type of a series

marks_series.dtype
# Out:
# dtype('int64')

# %%
# name of a series

marks_series.name
# Out:
# 'Arsalan ke Marks'

# %%
# is_unique

# this will show if all the values in the series are unique or not. 
# It will return True if all values are unique, otherwise it will return False.

marks_series.is_unique
# Out:
# True

# %%
# I just want to check whether the is_unique attribute is working or not. 
# So, I will create a new list with some duplicate values and then create a new Series from that list.

marks_new = [20, 15 ,20, 50, 95, 80]
subjects_new = ['Math', 'Science', 'English', 'History', 'Geography', 'Math']

marks_series_new = pd.Series(marks_new, index = subjects_new, name='Marks with Duplicates')
marks_series_new
# Out:
# Math         20
# Science      15
# English      20
# History      50
# Geography    95
# Math         80
# Name: Marks with Duplicates, dtype: int64

# %%
marks_series_new.is_unique
# Out:
# False

# %%
# index items

marks_series.index
# Out:
# Index(['Math', 'Science', 'English', 'History', 'Geography'], dtype='str')

# %%
# values (instead of index)

marks_series.values
# Out:
# array([85, 90, 78, 92, 88])

# %% [markdown]
# # Series using read_csv
#
# (i.e. reading an existing data set)

# %%
# csv files mean Comma Separated Values files.
# In such files, data is stored in a tabular format.
# each row represents a record and each column represents a field (attribute).

# I have already downloaded the three csv files which the teacher have used in the video. You can download them from the following links:
# https://raw.githubusercontent.com/arsal3646/Python_Projects/main/CampusX_Data_Science_Course/016_DataSets_Pandas/subs.csv

subs = pd.read_csv('https://raw.githubusercontent.com/arsal3646/Python_Projects/main/CampusX_Data_Science_Course/016_DataSets_Pandas/subs.csv')

subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
# Note: the type of the above object is automatically a DataFrame, not a Series.

type(subs)
# Out:
# pandas.DataFrame

# %%
# we need to convert the DataFrame into a Series.
# this is done by using Squeeze method, i.e. squeeze = True

subs_series = subs.squeeze() 

# you can also doing the same directly while reading the csv file by using the squeeze parameter.
# the code would have been like this:
# subs_series = pd.read_csv('https://raw.githubusercontent.com/arsal3646/Python_Projects/main/CampusX_Data_Science_Course/016_DataSets_Pandas/subs.csv', squeeze=True)

subs_series
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs_series.name

# the name of the Series is automatically set to the name of the column in the DataFrame.
# Out:
# 'Subscribers gained'

# %%
type(subs_series)

# now it is changed to a Series object from a DataFrame object.
# Out:
# pandas.Series

# %%
# Pandas Series - with one column

subs_series
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
import pandas as pd

urls = [
    "https://raw.githubusercontent.com/arsal3646/Python_Projects/main/CampusX_Data_Science_Course/016_DataSets_Pandas/kohli_ipl.csv",
    "https://raw.githubusercontent.com/arsal3646/Python_Projects/master/CampusX_Data_Science_Course/016_DataSets_Pandas/kohli_ipl.csv",
    "https://raw.githubusercontent.com/arsal3646/Python_Projects/main/CampusX_Data_Science_Course/016_DataSets_Pandas/kohli_runs.csv",
    "https://raw.githubusercontent.com/arsal3646/Python_Projects/master/CampusX_Data_Science_Course/016_DataSets_Pandas/kohli_runs.csv",
]

for url in urls:
    try:
        kohli = pd.read_csv(url, index_col="match_no").squeeze("columns")
        print("Loaded from:", url)
        break
    except Exception as e:
        print("Failed:", url)

kohli
# Out:
# Loaded from: https://raw.githubusercontent.com/arsal3646/Python_Projects/main/CampusX_Data_Science_Course/016_DataSets_Pandas/kohli_ipl.csv
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
# now let us use kohli_runs.csv file to create a Series with 2 columns.

import pandas as pd

kohli = pd.read_csv(
    'https://raw.githubusercontent.com/arsal3646/Python_Projects/main/CampusX_Data_Science_Course/016_DataSets_Pandas/kohli_ipl.csv',
    index_col='match_no'
).squeeze('columns')

kohli
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
bollywood = pd.read_csv(
    'https://raw.githubusercontent.com/arsal3646/Python_Projects/main/CampusX_Data_Science_Course/016_DataSets_Pandas/bollywood.csv'
)

bollywood
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
# Pandas Series -  with 2 columns  
 
bollywood_series = bollywood.squeeze('columns')

bollywood_series
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %% [markdown]
# # Series Methods

# %%
# head and tail methods

bollywood_series.head(3)  # this will show the first 3 rows of the Series
# Out:
#                                   movie           lead
# 0              Uri: The Surgical Strike  Vicky Kaushal
# 1                         Battalion 609    Vicky Ahuja
# 2  The Accidental Prime Minister (film)    Anupam Kher

# %%
kohli.head(3)  # this will show the first 3 rows of the Series
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# Name: runs, dtype: int64

# %%
kohli.tail(10)  # this will show the last 10 rows of the Series
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
bollywood_series.tail(8)  # this will show the last 8 rows of the Series
# Out:
#                            movie              lead
# 1492  Waisa Bhi Hota Hai Part II      Arshad Warsi
# 1493    Devdas (2002 Hindi film)    Shah Rukh Khan
# 1494                      Kaante  Amitabh Bachchan
# 1495      Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496         Aankhen (2002 film)  Amitabh Bachchan
# 1497             Saathiya (film)      Vivek Oberoi
# 1498              Company (film)        Ajay Devgn
# 1499        Awara Paagal Deewana      Akshay Kumar

# %%
# sample method shows a random sample of rows from the Series.

kohli.sample()
# Out:
# match_no
# 108    48
# Name: runs, dtype: int64

# %%
bollywood_series.sample(10)  # this will show a random sample of 10 rows from the Series
# Out:
#                                                movie                lead
# 494                                     Koyelaanchal  Kannan Arunachalam
# 548                       Happy New Year (2014 film)      Shah Rukh Khan
# 1061               Blood Brothers (2007 Indian film)           Jazzy Doe
# 339                                    Beiimaan Love         Sunny Leone
# 267                                     Ishq Forever  Krishna Chaturvedi
# 369                           Mumbai Can Dance Saala       Shakti Kapoor
# 406                                    Bombay Velvet       Ranbir Kapoor
# 1375  Netaji Subhas Chandra Bose: The Forgotten Hero         Vinay Anand
# 1469                             Parwana (2003 film)          Ajay Devgn
# 467                        Highway (2014 Hindi film)          Alia Bhatt

# %%
# value counts (based on lead as the Series has 2 columns.
# we can specify the column name to get the value counts for that column.

bollywood_series['lead'].value_counts()

# this is like countif() in Excel.
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values method sorts the values in the Series in ascending order by default.

# if we use the parameter ascending=False, it will sort the values in descending order.

bollywood['lead'].value_counts().sort_values(ascending=True)
# Out:
# lead
# Saurav Chakraborty     1
# Elisha Kriis           1
# Chandan Roy Sanyal     1
# Tinnu Anand            1
# Sumit Nijhawan         1
#                       ..
# Sanjay Dutt           26
# Salman Khan           31
# Ajay Devgn            38
# Amitabh Bachchan      45
# Akshay Kumar          48
# Name: count, Length: 566, dtype: int64

# %%
# How to find the highest and lowest values in a Series?

bollywood['lead'].value_counts().sort_values(ascending=False).head(1)  # this will show the highest value in the Series
# Out:
# lead
# Akshay Kumar    48
# Name: count, dtype: int64

# %%
bollywood['lead'].value_counts().sort_values(ascending=True).head(1)  # this will show the lowest value in the Series

# This is is called method chaining. It is a way to call multiple methods on an object in a single line of code.
# Method chaining can make the code more concise and readable 
# but it can also make it harder to debug if something goes wrong.
# Out:
# lead
# Saurav Chakraborty    1
# Name: count, dtype: int64

# %%
# inplace parameter is used to modify the "original" Series instead of creating a new one.

# inplace = True means that the original Series will be modified and the changes will be saved in the same Series object.

# %%
bollywood_series.count()  # this will show the number of non-null values in the Series
# Out:
# movie    1500
# lead     1500
# dtype: int64

# %%
subs_series.count()  # this will show the number of non-null values in the Series
# Out:
# np.int64(365)

# %%
subs_series.sum()
# Out:
# np.int64(49510)

# %%
subs_series.mean()  # this will show the mean of the values in the Series.

# on a daily basis, he is getting 135 new subscribers on his YouTube channel.
# Out:
# np.float64(135.64383561643837)

# %%
subs_series.median()  # this will show the median of the values in the Series
# Out:
# np.float64(123.0)

# %%
bollywood_series.mode() # this will show the mode of the values in the Series
# Out:
#                      movie          lead
# 0                   Andaaz  Akshay Kumar
# 1           Gabbar Is Back           NaN
# 2  Tanu Weds Manu: Returns           NaN

# %%
subs_series.std()  # this will show the standard deviation of the values in the Series
# Out:
# np.float64(62.6750230372527)

# %%
subs_series.var()  # this will show the variance of the values in the Series
# Out:
# np.float64(3928.1585127201565)

# %%
subs_series.min()  # this will show the minimum value in the Series
# Out:
# np.int64(33)

# %%
subs_series.max()
# Out:
# np.int64(396)

# %%
subs_series.describe()  # this will show the summary statistics of the values in the Series
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
bollywood_series.describe()  # this will show the summary statistics of the values in the Series
# Out:
#                           movie          lead
# count                      1500          1500
# unique                     1497           566
# top     Tanu Weds Manu: Returns  Akshay Kumar
# freq                          2            48

# %%
kohli.describe()  # this will show the summary statistics of the values in the Series
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
# slicing in Pandas

# It is similar to slicing in Python lists and NumPy arrays.

kohli[0:5]  # this will show the first 5 rows of the Series
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
kohli[5:10]  # this will show the rows from index 5 to 9 of the Series. It will not include the row at index 10.
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# Name: runs, dtype: int64

# %%
# check last five rows of the Series

bollywood_series[-5:]  # this will show the last 5 rows of the Series
# Out:
#                        movie              lead
# 1495  Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496     Aankhen (2002 film)  Amitabh Bachchan
# 1497         Saathiya (film)      Vivek Oberoi
# 1498          Company (film)        Ajay Devgn
# 1499    Awara Paagal Deewana      Akshay Kumar

# %%
# fancy indexing in Pandas

# fancy indexing is a way to select specific rows from a Series using a list of indices rather than using a range of indices or a pattern.

kohli[[1, 2, 4]]  # this will show the rows at index 1, 2, and 4 of the Series
# Out:
# match_no
# 1     1
# 2    23
# 4    12
# Name: runs, dtype: int64

# %%
# Series with Python Functionalities

# You can use Python's built-in functions and methods on Pandas Series.
# For example, you can use len(), min(), max(), sum(), and other functions.

len(kohli)  # this will return the number of elements in the Series
# Out:
# 215

# %%
min(kohli)  # this will return the minimum value in the Series
# Out:
# 0

# %%
max(kohli)  # this will return the maximum value in the Series
# Out:
# 113

# %%
sum(kohli)  # this will return the sum of all values in the Series
# Out:
# 6634

# %%
type(subs)
# Out:
# pandas.DataFrame

# %%
type(subs_series)
# Out:
# pandas.Series

# %%
# See list of all available methods and attributes of a Series object.

# You can use the dir() function to see a list of all available methods and attributes of a Series object.

dir(subs_series)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
sorted(subs_series) # this will return a sorted list of all values in the Series

# the output is a LIST.
# Out:
# [33,
#  33,
#  35,
#  37,
#  39,
#  40,
#  40,
#  40,
#  40,
#  42,
#  42,
#  43,
#  44,
#  44,
#  44,
#  45,
#  46,
#  46,
#  48,
#  49,
#  49,
#  49,
#  49,
#  50,
#  50,
#  50,
#  51,
#  54,
#  56,
#  56,
#  56,
#  56,
#  57,
#  61,
#  62,
#  64,
#  65,
#  65,
#  66,
#  66,
#  66,
#  66,
#  67,
#  68,
#  70,
#  70,
#  70,
#  71,
#  71,
#  72,
#  72,
#  72,
#  72,
#  72,
#  73,
#  74,
#  74,
#  75,
#  76,
#  76,
#  76,
#  76,
#  77,
#  77,
#  78,
#  78,
#  78,
#  79,
#  79,
#  80,
#  80,
#  80,
#  81,
#  81,
#  82,
#  82,
#  83,
#  83,
#  83,
#  84,
#  84,
#  84,
#  85,
#  86,
#  86,
#  86,
#  87,
#  87,
#  87,
#  87,
#  88,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  89,
#  90,
#  90,
#  90,
#  90,
#  91,
#  92,
#  92,
#  92,
#  93,
#  93,
#  93,
#  93,
#  95,
#  95,
#  96,
#  96,
#  96,
#  96,
#  97,
#  97,
#  98,
#  98,
#  99,
#  99,
#  100,
#  100,
#  100,
#  101,
#  101,
#  101,
#  102,
#  102,
#  103,
#  103,
#  104,
#  104,
#  104,
#  105,
#  105,
#  105,
#  105,
#  105,
# ...

# %% [markdown]
# Studied until min 1 hour 40 min
